# %% [markdown]
# # TASK - 2 DAI

# %%
import pandas as pd

# %%
data=pd.read_csv("forbes_the_global_2000_2023update.csv")
data
# Out:
#       rank                                   company        country   sales  \
# 0        1                            JPMorgan Chase  United States  179930
# 1        2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  589470
# 2        3                                      ICBC          China  216770
# 3        4                   China Construction Bank          China  203080
# 4        5                Agricultural Bank of China          China  186140
# ...    ...                                       ...            ...     ...
# 1995  1996                                Alfa Laval         Sweden    5350
# 1996  1996                                       Gap  United States   15620
# 1997  1996                                  Yes Bank          India    3340
# 1998  1999                                 BEKB-BCBE    Switzerland     556
# 1999  1999                                     Ipsen         France    3180
#
#         profit    asset  market_value  publish_year
# ...

# %%
data.head((10))
# Out:
#    rank                                   company        country   sales  \
# 0     1                            JPMorgan Chase  United States  179930
# 1     2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  589470
# 2     3                                      ICBC          China  216770
# 3     4                   China Construction Bank          China  203080
# 4     5                Agricultural Bank of China          China  186140
# 5     6                           Bank of America  United States  133840
# 6     7                                  Alphabet  United States  282850
# 7     8                                ExxonMobil  United States  393160
# 8     9                                 Microsoft  United States  207590
# 9    10                                     Apple  United States  385100
#
#      profit    asset  market_value  publish_year
# 0   41800.0  3744300        399590          2023
# 1  156360.0   660990       2055220          2023
# ...

# %% [markdown]
# # TASK - 3 DAI

# %%
data.shape
# Out:
# (2000, 8)

# %%
data.dtypes # data types of each columns in the dataframe
# Out:
# rank              int64
# company          object
# country          object
# sales             int64
# profit          float64
# asset             int64
# market_value      int64
# publish_year      int64
# dtype: object

# %%
data.isnull().sum() # Checking null values
# Out:
# rank            0
# company         0
# country         0
# sales           0
# profit          0
# asset           0
# market_value    0
# publish_year    0
# dtype: int64

# %%
data.isna().values.any() # Checking missing values
# Out:
# False

# %% [markdown]
# # TASK - 4

# %%
data.describe()  # summary statictics of dataframe
# Out:
#               rank          sales         profit         asset  market_value  \
# count  2000.000000    2000.000000    2000.000000  2.000000e+03  2.000000e+03
# mean   1000.309500   25422.386000    2208.305500  1.158463e+05  3.699562e+04
# std     577.395083   46517.168841    6632.030642  3.722422e+05  1.142306e+05
# min       1.000000 -109990.000000  -76170.000000  1.050000e+02  3.200000e+01
# 25%     500.750000    5770.000000     494.850000  1.472000e+04  6.860000e+03
# 50%    1000.500000   12500.000000     961.300000  3.165500e+04  1.531000e+04
# 75%    1499.500000   25170.000000    2202.500000  7.697250e+04  3.404250e+04
# max    1999.000000  611290.000000  156360.000000  6.116820e+06  2.746210e+06
#
#        publish_year
# count        2000.0
# mean         2023.0
# std             0.0
# min          2023.0
# 25%          2023.0
# 50%          2023.0
# 75%          2023.0
# max          2023.0

# %% [markdown]
# # TASK - 5
# Unique values count in each categorical column

# %%
Unique_Companies= data['company'].value_counts()
Unique_Companies
# Out:
# JPMorgan Chase         1
# China CSSC Holdings    1
# Bluescope Steel        1
# Umicore                1
# Synovus                1
#                       ..
# Hindalco Industries    1
# Equitable Holdings     1
# Prudential             1
# Gallagher              1
# Ipsen                  1
# Name: company, Length: 2000, dtype: int64

# %%
countries_count=data['country'].value_counts()
countries_count
# Out:
# United States           610
# China                   302
# Japan                   192
# United Kingdom           67
# South Korea              59
# Canada                   57
# India                    55
# Germany                  53
# France                   52
# Taiwan                   45
# Hong Kong                44
# Switzerland              44
# Australia                32
# Italy                    28
# Netherlands              25
# Sweden                   24
# Brazil                   22
# Ireland                  22
# Spain                    20
# Thailand                 17
# Saudi Arabia             17
# United Arab Emirates     16
# Singapore                14
# Mexico                   13
# South Africa             12
# Israel                   11
# Denmark                  10
# Finland                  10
# Austria                   9
# Turkey                    9
# Norway                    9
# Chile                     8
# Indonesia                 8
# ...

# %%
years_count=data['publish_year'].value_counts()
years_count
# Out:
# 2023    2000
# Name: publish_year, dtype: int64

# %%
correlation=data.corr()
correlation
# Out:
#                   rank     sales    profit     asset  market_value  \
# rank          1.000000 -0.488154 -0.383482 -0.321138     -0.316817
# sales        -0.488154  1.000000  0.603346  0.319704      0.534500
# profit       -0.383482  0.603346  1.000000  0.368999      0.711521
# asset        -0.321138  0.319704  0.368999  1.000000      0.143805
# market_value -0.316817  0.534500  0.711521  0.143805      1.000000
# publish_year       NaN       NaN       NaN       NaN           NaN
#
#               publish_year
# rank                   NaN
# sales                  NaN
# profit                 NaN
# asset                  NaN
# market_value           NaN
# publish_year           NaN
